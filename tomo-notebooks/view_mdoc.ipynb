# %%
import mdocfile
import pandas as pd

# %%
fn = 'DATA/sconnell_20240220_ecoli_lamella/Position_9.mdoc'

# %%
df = mdocfile.read(fn)

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    ZValue  TiltAngle       StagePosition  StageZ  Magnification  MagIndex  \
# 0       0      -15.0  (-399.09, -262.18)   60.17        64000.0        29
# 1       1      -18.0  (-399.08, -262.23)   60.17        64000.0        29
# 2       2      -21.0  (-399.08, -262.26)   60.17        64000.0        29
# 3       3      -12.0  (-399.09, -262.18)   60.17        64000.0        29
# 4       4       -9.0  (-399.08, -262.16)   60.17        64000.0        29
#
#    Intensity  PixelSpacing  ExposureDose  SpotSize  Defocus  TargetDefocus  \
# 0        0.0          2.71          1.39       5.0    -4.75           -3.0
# 1        0.0          2.71          1.38       5.0    -4.76           -3.0
# 2        0.0          2.71          1.37       5.0    -4.75           -3.0
# 3        0.0          2.71          1.40       5.0    -4.71           -3.0
# 4        0.0          2.71          1.40       5.0    -4.67           -3.0
#
#        ImageShift  RotationAngle  ExposureTime  Binning  \
# ...

# %%
print(df['SubFramePath'][0])
# Out:
# \\192.168.12.2\DoseFractions\sconnell_20240220_ecoli_lamella\Position_9_2_001_-15.00_20240220_212525_Fractions.mrc
